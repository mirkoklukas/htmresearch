# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from htmresearch.support.gridcells.utils import map_to_quotient, hexagonal_basis, compute_grid
from scipy.stats import entropy
from mpl_toolkits.mplot3d import Axes3D
# %load_ext autoreload
# %autoreload 2






fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
s     = 1.0
v = np.array([0.,0.])

theta = 0.
B = s*hexagonal_basis(theta)

L = compute_grid(B, 4) + v

V = np.array([
    [1  , 0 ],
    [0  , 1 ],
    [1., 1.]
])

L_ = np.dot(L,V.T)

M =np.array([
    [1 , 0 , 0.4],
    [0., 1 , 0.1]
])

Z = np.dot(L_, M.T)

print Z.shape

# plt.figure(figsize=(5,5))
# plt.title("Square environment")
# plt.xlim(-2,2)
# plt.ylim(-2,2)
ax.scatter(L_[:,0],L_[:,1], L_[:,2], label="Shaping lattice")
plt.legend()
plt.show()

plt.scatter(Z[:,0], Z[:,1])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (81, 2)

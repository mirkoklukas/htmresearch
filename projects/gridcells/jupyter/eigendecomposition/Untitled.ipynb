# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2


from itertools import product
n = 20


T = np.zeros((n**2,n**2))

img = np.zeros((n,n))

for (p1, p2) in product(range(n), repeat=2):
    for (q1, q2) in product(range(n), repeat=2):
        dist = np.sqrt((p1-q1)**2 + (p2-q2)**2)
        T[p1*n + p2, q1*n + q2] = dist

        
# np.fill_diagonal(T, 0.0)


# T = (T > 0.2).astype(float)


T /= np.sum(T, axis=1, keepdims=True)

T = (T + T.transpose())/2.

# T /= np.sum(T, axis=1, keepdims=True)


plt.imshow(T[np.random.randint(n**2)].reshape((n,n)) )
plt.show()
plt.imshow(T )
plt.show()
val, vec = np.linalg.eigh(T)


plt.plot(val)
plt.show()
plt.imshow(vec[0].reshape((n,n)), vmin=0, vmax=0.1)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
##### 
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ortho_group
from scipy.stats import entropy
from scipy import sparse

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2


n = 100
T = 100
X = np.zeros((n,T))
X[:] = np.linspace(0.,100., num=T)

w = np.linspace(0.1,1., num=n).reshape((-1,1))
# w = np.ones((n,1))
p=0.
# p = np.linspace(0.,np.pi*2., num=n).reshape((-1,1))
C = np.cos(w*X + p)


dC = w*np.sin(w*X + p)
ddC = - (w**2.)*np.cos(w*X + p)

e1 = dC/(np.sum(dC**2., axis=0, keepdims=True)**0.5)

e2 = ddC - np.sum(e1*ddC, axis=0, keepdims=True)*e1
e2 = e2/(np.sum(e2**2, axis=0, keepdims=True)**0.5)

plt.figure(figsize=(20,20))
plt.imshow(C)
plt.show()

plt.plot(np.sum(C**2, axis=0))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/mklukas/Library/Python/2.7/lib/python/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in divide

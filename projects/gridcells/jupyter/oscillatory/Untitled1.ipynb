# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline




n = 1000
m = 4
w = np.zeros(n)
z = np.zeros(n)

t = np.linspace(0.,100.,num=1000).reshape((-1,1))*np.pi*2.

I = np.indices((n,n)).reshape((2,-1)).T

for i in range(m):
    r = np.random.sample()
    w[i*(n//m):(i+1)*(n//m)] = r
    z[i*(n//m):(i+1)*(n//m)] = np.linspace(0.,r*np.pi*2., num=n//m, endpoint=False)

# w = np.linspace(0.1,1., num=n)
# z = np.linspace(0.1,1., num=n)

plt.scatter(w,z)
plt.show()
# print np.sin(w*t + z).shape

plt.imshow(np.cos(w*t + z))
print np.sum(w**2*np.sin(w*t + z)*np.cos(w*t + z))**2/len(t)
# Out:
# 0.116949234253

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diam = 100.
res = 100
x = np.indices((res,res)).reshape((2,-1)).T/float(res)
x = x*diam

a = np.array([
    [np.cos(0), np.cos(np.pi/3.), np.cos(2*np.pi/3.)],
    [np.sin(0), np.sin(np.pi/3.), np.sin(2*np.pi/3.)]
])



# gamma = np.cos( np.dot(x,a[0]) + np.dot(t*v,a[0]) + z1) 

print np.indices((100,100)).reshape((2,-1)).T.shape

g = np.dot(x - (1,50), 0.1*a)
print g.shape

img = np.cos(g[:,0]) + np.cos(g[:,1]) + np.cos(g[:,2]) 
print img.shape
plt.imshow(img.reshape((100,100)))
# Out:
# (10000, 2)
# (10000, 3)
# (10000,)

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2


from htmresearch.support.autoencoder.sparse_hopfield_coder import SparseHopfieldCoder


model = SparseHopfieldCoder()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_mldata
from sklearn.neural_network import MLPClassifier

mnist = fetch_mldata("MNIST original")
# rescale the data, use the traditional train/test split
X, y = mnist.data / 255., mnist.target

X = 2.0*X - 1.0

X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

N=100
lam=1.0

# A = model.encode(X_train[[0]].T, N, lam)

# plt.imshow(A[-1].reshape((10,10)))

losses, Y, S_hat = model.fit(X_train[:1000], N, lam)
plt.plot(losses)

# %%
plt.imshow(Y[-13].reshape((10,10)))
plt.show()
plt.imshow(S_hat[-1].reshape((28,28)))
